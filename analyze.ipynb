# %%
import pandas as pd

# Show all columns (no "..." in the middle)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", 50)

# Load results from batch run
results_path = "results/distance_multi-camera-leo-geo.csv"
df = pd.read_csv(results_path)

print(f"Loaded {len(df)} rows. Columns: {list(df.columns)}")
# Out:
# Loaded 18900 rows. Columns: ['Unnamed: 0', 'true_pos_x', 'true_pos_y', 'true_pos_z', 'qw', 'qx', 'qy', 'qz', 'shape_axis_a', 'shape_axis_b', 'shape_axis_c', 'cam_focal_length', 'cam_x_pixel_pitch', 'cam_y_pixel_pitch', 'cam_x_resolution', 'cam_y_resolution', 'cam_x_center', 'cam_y_center', 'out_pos_x', 'out_pos_y', 'out_pos_z', 'runtime_sec', 'instructions', 'bytes_allocated', 'allocations', 'true_x_centroid', 'true_y_centroid', 'true_r_apparent', 'out_x_centroid', 'out_y_centroid', 'out_r_apparent', 'position_distance_error_m', 'atmosphere_blur']

# %%
# Only input position, orientation (quat), and output position
df
# Out:
#        Unnamed: 0    true_pos_x    true_pos_y    true_pos_z            qw  \
# 0               0  2.414891e+06  0.000000e+00  6.356752e+06  6.123234e-17
# 1               1  2.414891e+06  0.000000e+00  6.356752e+06  6.122870e-17
# 2               2  2.414891e+06  0.000000e+00  6.356752e+06  4.953800e-17
# 3               3  2.414891e+06  0.000000e+00  6.356752e+06 -6.411615e-03
# 4               4  2.414891e+06  0.000000e+00  6.356752e+06  1.892183e-17
# ...           ...           ...           ...           ...           ...
# 18895       18895  2.145921e+07 -2.690900e+07  6.356752e+06 -1.675380e-02
# 18896       18896  2.145921e+07 -2.690900e+07  6.356752e+06 -1.340774e-01
# 18897       18897  2.145921e+07 -2.690900e+07  6.356752e+06 -2.808348e-01
# 18898       18898  2.145921e+07 -2.690900e+07  6.356752e+06  3.510193e-01
# 18899       18899  2.145921e+07 -2.690900e+07  6.356752e+06  4.376465e-01
#
#                  qx            qy        qz  shape_axis_a  shape_axis_b  \
# 0      0.000000e+00  0.000000e+00  1.000000     6378137.0     6378137.0
# 1     -1.090809e-02  6.679280e-19  0.999941     6378137.0     6378137.0
# 2      3.599147e-17  5.877853e-01  0.809017     6378137.0     6378137.0
# 3     -8.824831e-03  5.877503e-01  0.808969     6378137.0     6378137.0
# 4      5.823542e-17  9.510565e-01  0.309017     6378137.0     6378137.0
# ...             ...           ...       ...           ...           ...
# 18895  3.580327e-01  8.671368e-01  0.345841     6378137.0     6378137.0
# 18896  4.126480e-01  8.568723e-01 -0.278415     6378137.0     6378137.0
# 18897  4.547251e-01  8.205722e-01 -0.202529     6378137.0     6378137.0
# 18898 -2.550305e-01 -5.295762e-01  0.728899     6378137.0     6378137.0
# 18899 -3.777280e-01 -4.605769e-01  0.673540     6378137.0     6378137.0
#
#        shape_axis_c  cam_focal_length  cam_x_pixel_pitch  cam_y_pixel_pitch  \
# 0      6.356752e+06          0.029317           0.000005           0.000005
# 1      6.356752e+06          0.029317           0.000005           0.000005
# 2      6.356752e+06          0.029317           0.000005           0.000005
# 3      6.356752e+06          0.029317           0.000005           0.000005
# 4      6.356752e+06          0.029317           0.000005           0.000005
# ...             ...               ...                ...                ...
# 18895  6.356752e+06          0.006102           0.000005           0.000005
# 18896  6.356752e+06          0.006102           0.000005           0.000005
# 18897  6.356752e+06          0.006102           0.000005           0.000005
# 18898  6.356752e+06          0.006102           0.000005           0.000005
# 18899  6.356752e+06          0.006102           0.000005           0.000005
#
#        cam_x_resolution  cam_y_resolution  cam_x_center  cam_y_center  \
# 0                   512               512         256.0         256.0
# 1                   512               512         256.0         256.0
# 2                   512               512         256.0         256.0
# 3                   512               512         256.0         256.0
# 4                   512               512         256.0         256.0
# ...                 ...               ...           ...           ...
# 18895              2048              2048        1024.0        1024.0
# 18896              2048              2048        1024.0        1024.0
# 18897              2048              2048        1024.0        1024.0
# 18898              2048              2048        1024.0        1024.0
# 18899              2048              2048        1024.0        1024.0
#
#         out_pos_x     out_pos_y  out_pos_z  runtime_sec  instructions  \
# 0       2423090.0 -0.000000e+00  6356750.0          NaN           NaN
# 1       2405130.0 -0.000000e+00  6356750.0          NaN           NaN
# 2       2414950.0  3.269850e+00  6356750.0          NaN           NaN
# 3       2410560.0 -7.655170e+01  6356750.0          NaN           NaN
# 4       2411860.0  4.095280e+01  6356750.0          NaN           NaN
# ...           ...           ...        ...          ...           ...
# 18895  21459200.0 -2.690900e+07  6356750.0          NaN           NaN
# 18896  21459200.0 -2.690900e+07  6356750.0          NaN           NaN
# 18897  21459200.0 -2.690900e+07  6356750.0          NaN           NaN
# 18898  21459200.0 -2.690900e+07  6356770.0          NaN           NaN
# 18899  21459200.0 -2.690900e+07  6356750.0          NaN           NaN
#
#        bytes_allocated  allocations  true_x_centroid  true_y_centroid  \
# 0                  NaN          NaN              NaN              NaN
# 1                  NaN          NaN              NaN              NaN
# 2                  NaN          NaN              NaN              NaN
# 3                  NaN          NaN              NaN              NaN
# 4                  NaN          NaN              NaN              NaN
# ...                ...          ...              ...              ...
# 18895              NaN          NaN              NaN              NaN
# 18896              NaN          NaN              NaN              NaN
# 18897              NaN          NaN              NaN              NaN
# 18898              NaN          NaN              NaN              NaN
# 18899              NaN          NaN              NaN              NaN
#
#        true_r_apparent  out_x_centroid  out_y_centroid  out_r_apparent  \
# 0                  NaN             NaN             NaN             NaN
# 1                  NaN             NaN             NaN             NaN
# 2                  NaN             NaN             NaN             NaN
# 3                  NaN             NaN             NaN             NaN
# 4                  NaN             NaN             NaN             NaN
# ...                ...             ...             ...             ...
# 18895              NaN             NaN             NaN             NaN
# 18896              NaN             NaN             NaN             NaN
# 18897              NaN             NaN             NaN             NaN
# 18898              NaN             NaN             NaN             NaN
# 18899              NaN             NaN             NaN             NaN
#
#        position_distance_error_m  atmosphere_blur
# 0                            NaN              0.0
# 1                            NaN              0.0
# 2                            NaN              0.0
# 3                            NaN              0.0
# 4                            NaN              0.0
# ...                          ...              ...
# 18895                        NaN              0.0
# 18896                        NaN              0.0
# 18897                        NaN              0.0
# 18898                        NaN              0.0
# 18899                        NaN              0.0
#
# [18900 rows x 33 columns]

# %%
from limb.simulation.analysis.metrics import fill_pixel_metrics

# Ensure metric columns exist so fill_pixel_metrics can fill them
metric_cols = [
    "true_x_centroid", "true_y_centroid", "true_r_apparent",
    "out_x_centroid", "out_y_centroid", "out_r_apparent",
]
for c in metric_cols:
    if c not in df.columns:
        df[c] = float("nan")

df = fill_pixel_metrics(df)

# Show position, orientation, output position, and filled centroid/r
cols = [
    "true_pos_x", "true_pos_y", "true_pos_z",
    "qx", "qy", "qz", "qw",
    "out_pos_x", "out_pos_y", "out_pos_z",
    "true_x_centroid", "true_y_centroid", "true_r_apparent",
    "out_x_centroid", "out_y_centroid", "out_r_apparent",
]
cols = [c for c in cols if c in df.columns]
df[cols]
# Out:
#          true_pos_x    true_pos_y    true_pos_z            qx            qy  \
# 0      2.414891e+06  0.000000e+00  6.356752e+06  0.000000e+00  0.000000e+00
# 1      2.414891e+06  0.000000e+00  6.356752e+06 -1.090809e-02  6.679280e-19
# 2      2.414891e+06  0.000000e+00  6.356752e+06  3.599147e-17  5.877853e-01
# 3      2.414891e+06  0.000000e+00  6.356752e+06 -8.824831e-03  5.877503e-01
# 4      2.414891e+06  0.000000e+00  6.356752e+06  5.823542e-17  9.510565e-01
# ...             ...           ...           ...           ...           ...
# 18895  2.145921e+07 -2.690900e+07  6.356752e+06  3.580327e-01  8.671368e-01
# 18896  2.145921e+07 -2.690900e+07  6.356752e+06  4.126480e-01  8.568723e-01
# 18897  2.145921e+07 -2.690900e+07  6.356752e+06  4.547251e-01  8.205722e-01
# 18898  2.145921e+07 -2.690900e+07  6.356752e+06 -2.550305e-01 -5.295762e-01
# 18899  2.145921e+07 -2.690900e+07  6.356752e+06 -3.777280e-01 -4.605769e-01
#
#              qz            qw   out_pos_x     out_pos_y  out_pos_z  \
# 0      1.000000  6.123234e-17   2423090.0 -0.000000e+00  6356750.0
# 1      0.999941  6.122870e-17   2405130.0 -0.000000e+00  6356750.0
# 2      0.809017  4.953800e-17   2414950.0  3.269850e+00  6356750.0
# 3      0.808969 -6.411615e-03   2410560.0 -7.655170e+01  6356750.0
# 4      0.309017  1.892183e-17   2411860.0  4.095280e+01  6356750.0
# ...         ...           ...         ...           ...        ...
# 18895  0.345841 -1.675380e-02  21459200.0 -2.690900e+07  6356750.0
# 18896 -0.278415 -1.340774e-01  21459200.0 -2.690900e+07  6356750.0
# 18897 -0.202529 -2.808348e-01  21459200.0 -2.690900e+07  6356750.0
# 18898  0.728899  3.510193e-01  21459200.0 -2.690900e+07  6356770.0
# 18899  0.673540  4.376465e-01  21459200.0 -2.690900e+07  6356750.0
#
#        true_x_centroid  true_y_centroid  true_r_apparent  out_x_centroid  \
# 0           256.000000     15690.215392      5499.608639      256.000000
# 1           256.000000     14730.878444      5499.608639      256.000000
# 2         14934.811123      5025.434851      5499.608639    14934.446560
# 3         14682.252110      4816.550130      5499.608639    14707.781149
# 4          9328.004188    -12230.542547      5499.608639     9339.483420
# ...                ...              ...              ...             ...
# 18895      1173.092440       361.448918       222.388449     1173.092113
# 18896       891.518249       841.654513       222.388449      891.518033
# 18897       874.907560       361.448918       222.388449      874.907328
# 18898       809.640024      1093.649778       222.388449      809.639512
# 18899       800.525122       657.098284       222.388449      800.525309
#
#        out_y_centroid  out_r_apparent
# 0        15637.987042     5497.253094
# 1        14786.907916     5502.410484
# 2         5025.324745     5499.593531
# 3         4824.654536     5500.853724
# 4       -12246.172975     5500.480695
# ...               ...             ...
# 18895      361.448752      222.388465
# 18896      841.654754      222.388465
# 18897      361.449223      222.388465
# 18898     1093.650278      222.388442
# 18899      657.098589      222.388465
#
# [18900 rows x 16 columns]

# %%
import numpy as np

# Pixel error = Euclidean distance between true and output centroid (pixels)
valid = (
    df["out_x_centroid"].notna()
    & df["out_y_centroid"].notna()
    & df["true_x_centroid"].notna()
    & df["true_y_centroid"].notna()
)
pixel_error = np.sqrt(
    (df.loc[valid, "out_x_centroid"] - df.loc[valid, "true_x_centroid"]) ** 2
    + (df.loc[valid, "out_y_centroid"] - df.loc[valid, "true_y_centroid"]) ** 2
)
df_with_error = df.loc[valid].copy()
df_with_error = df_with_error.assign(pixel_error=pixel_error.values)

top10_pixel_errors = df_with_error.nlargest(10, "pixel_error")

# Position error = Euclidean distance between true and output position (meters)
valid_pos = (
    df["true_pos_x"].notna() & df["true_pos_y"].notna() & df["true_pos_z"].notna()
    & df["out_pos_x"].notna() & df["out_pos_y"].notna() & df["out_pos_z"].notna()
)
position_error = np.sqrt(
    (df.loc[valid_pos, "out_pos_x"] - df.loc[valid_pos, "true_pos_x"]) ** 2
    + (df.loc[valid_pos, "out_pos_y"] - df.loc[valid_pos, "true_pos_y"]) ** 2
    + (df.loc[valid_pos, "out_pos_z"] - df.loc[valid_pos, "true_pos_z"]) ** 2
)
df_with_pos_error = df.loc[valid_pos].copy()
df_with_pos_error = df_with_pos_error.assign(position_error=position_error.values)

top10_position_errors = df_with_pos_error.nlargest(10, "position_error")

# Mean difference in norm (position: ‖out - true‖ in m; pixel: ‖out_centroid - true_centroid‖ in px)
mean_position_error_m = df_with_pos_error["position_error"].mean()
mean_pixel_error_px = df_with_error["pixel_error"].mean()
print(f"Mean position error (norm of difference, m): {mean_position_error_m:.4f}")
print(f"Mean pixel error (norm of difference, px):    {mean_pixel_error_px:.4f}")

cols = [
    "true_pos_x", "true_pos_y", "true_pos_z",
    "qx", "qy", "qz", "qw",
    "out_pos_x", "out_pos_y", "out_pos_z",
    "true_x_centroid", "true_y_centroid", "true_r_apparent",
    "out_x_centroid", "out_y_centroid", "out_r_apparent",
]
cols = [c for c in cols if c in df.columns]
print("Top 10 pixel errors (centroid residual, px):")
display(top10_pixel_errors[cols + ["pixel_error"]])
print("\nTop 10 position errors (3D residual, m):")
display(top10_position_errors[cols + ["position_error"]])
# Out:
# Mean position error (norm of difference, m): 451.8226
# Mean pixel error (norm of difference, px):    0.7890
# Top 10 pixel errors (centroid residual, px):
#       true_pos_x    true_pos_y    true_pos_z        qx            qy  \
# 11  1.505660e+06  1.888038e+06  6.356752e+06 -0.009828 -4.732844e-03
# 61  1.505660e+06 -1.888038e+06  6.356752e+06 -0.009828  4.732844e-03
# 31 -2.175742e+06  1.047782e+06  6.356752e+06  0.002427  1.063460e-02
# 41 -2.175742e+06 -1.047782e+06  6.356752e+06 -0.002427  1.063460e-02
# 1   2.414891e+06  0.000000e+00  6.356752e+06 -0.010908  6.679280e-19
# 21 -5.373639e+05  2.354345e+06  6.356752e+06  0.006801  8.528289e-03
# 51 -5.373639e+05 -2.354345e+06  6.356752e+06 -0.006801  8.528289e-03
# 20 -5.373639e+05  2.354345e+06  6.356752e+06  0.000000  0.000000e+00
# 50 -5.373639e+05 -2.354345e+06  6.356752e+06  0.000000  0.000000e+00
# 40 -2.175742e+06 -1.047782e+06  6.356752e+06  0.000000  0.000000e+00
#
#           qz            qw  out_pos_x  out_pos_y  out_pos_z  true_x_centroid  \
# 11  0.900915 -4.338579e-01  1499570.0  1880400.0  6356750.0            256.0
# 61  0.900915  4.338579e-01  1499570.0 -1880400.0  6356750.0            256.0
# 31 -0.222508  9.748699e-01 -2166940.0  1043550.0  6356750.0            256.0
# 41  0.222508  9.748699e-01 -2166940.0 -1043550.0  6356750.0            256.0
# 1   0.999941  6.122870e-17  2405130.0       -0.0  6356750.0            256.0
# 21 -0.623453  7.817850e-01  -535191.0  2344830.0  6356750.0            256.0
# 51  0.623453  7.817850e-01  -535191.0 -2344830.0  6356750.0            256.0
# 20 -0.623490  7.818315e-01  -539189.0  2362340.0  6356750.0            256.0
# 50  0.623490  7.818315e-01  -539189.0 -2362340.0  6356750.0            256.0
# 40  0.222521  9.749279e-01 -2183130.0 -1051340.0  6356750.0            256.0
#
#     true_y_centroid  true_r_apparent  out_x_centroid  out_y_centroid  \
# 11     14730.878444      5499.608639      256.001874    14786.951009
# 61     14730.878444      5499.608639      255.998126    14786.951009
# 31     14730.878444      5499.608639      256.013908    14786.937566
# 41     14730.878444      5499.608639      255.986092    14786.937566
# 1      14730.878444      5499.608639      256.000000    14786.907916
# 21     14730.878444      5499.608639      256.002576    14786.899747
# 51     14730.878444      5499.608639      255.997424    14786.899747
# 20     15690.215392      5499.608639      255.999267    15637.974067
# 50     15690.215392      5499.608639      256.000733    15637.974067
# 40     15690.215392      5499.608639      255.999995    15637.977553
#
#     out_r_apparent  pixel_error
# 11     5502.412627    56.072565
# 61     5502.412627    56.072565
# 31     5502.411958    56.059124
# 41     5502.411958    56.059124
# 1      5502.410484    56.029472
# 21     5502.410078    56.021303
# 51     5502.410078    56.021303
# 20     5497.252505    52.241325
# 50     5497.252505    52.241325
# 40     5497.252663    52.237840
# Top 10 position errors (3D residual, m):
#        true_pos_x    true_pos_y    true_pos_z        qx            qy  \
# 241 -3.233675e+06  1.557256e+06  6.356752e+06  0.002427  1.063460e-02
# 251 -3.233675e+06 -1.557256e+06  6.356752e+06 -0.002427  1.063460e-02
# 221  2.237773e+06  2.806078e+06  6.356752e+06 -0.009828 -4.732844e-03
# 271  2.237773e+06 -2.806078e+06  6.356752e+06 -0.009828  4.732844e-03
# 211  3.589109e+06  0.000000e+00  6.356752e+06 -0.010908  6.679280e-19
# 231 -7.986518e+05  3.499122e+06  6.356752e+06  0.006801  8.528289e-03
# 261 -7.986518e+05 -3.499122e+06  6.356752e+06 -0.006801  8.528289e-03
# 141  3.162546e+06  0.000000e+00  6.356752e+06 -0.010908  6.679280e-19
# 191 -7.037328e+05 -3.083255e+06  6.356752e+06 -0.006801  8.528289e-03
# 161 -7.037328e+05  3.083255e+06  6.356752e+06  0.006801  8.528289e-03
#
#            qz            qw  out_pos_x     out_pos_y  out_pos_z  \
# 241 -0.222508  9.748699e-01 -3224470.0  1.552830e+06  6356760.0
# 251  0.222508  9.748699e-01 -3224470.0 -1.552830e+06  6356760.0
# 221  0.900915 -4.338579e-01  2231410.0  2.798090e+06  6356760.0
# 271  0.900915  4.338579e-01  2231410.0 -2.798090e+06  6356760.0
# 211  0.999941  6.122870e-17  3578900.0 -1.033980e-25  6356760.0
# 231 -0.623453  7.817850e-01  -796380.0  3.489170e+06  6356760.0
# 261  0.623453  7.817850e-01  -796380.0 -3.489170e+06  6356760.0
# 141  0.999941  6.122870e-17  3152620.0 -0.000000e+00  6356760.0
# 191  0.623453  7.817850e-01  -701525.0 -3.073580e+06  6356760.0
# 161 -0.623453  7.817850e-01  -701525.0  3.073580e+06  6356760.0
#
#      true_x_centroid  true_y_centroid  true_r_apparent  out_x_centroid  \
# 241            256.0     10131.163234      5122.923116      256.010076
# 251            256.0     10131.163234      5122.923116      255.989924
# 221            256.0     10131.163234      5122.923116      256.009479
# 271            256.0     10131.163234      5122.923116      255.990521
# 211            256.0     10131.163234      5122.923116      256.000000
# 231            256.0     10131.163234      5122.923116      256.000436
# 261            256.0     10131.163234      5122.923116      255.999564
# 141            256.0     11423.686518      5267.230810      256.000000
# 191            256.0     11423.686518      5267.230810      256.000733
# 161            256.0     11423.686518      5267.230810      255.999267
#
#      out_y_centroid  out_r_apparent  position_error
# 241    10158.657490     5126.441092    10213.759337
# 251    10158.657490     5126.441092    10213.759337
# 221    10158.653552     5126.440589    10212.299663
# 271    10158.653552     5126.440589    10212.299663
# 211    10158.643384     5126.439290    10208.529441
# 231    10158.642184     5126.439137    10208.084713
# 261    10158.642184     5126.439137    10208.084713
# 141    11457.766590     5270.503775     9926.447747
# 191    11457.756503     5270.502807     9923.517239
# 161    11457.756503     5270.502807     9923.517239

# %%
import numpy as np
from limb.simulation.analysis.plot import (
    plot_centroid_residuals_in_illumination_frame,
    plot_radius_residuals_vs_range,
)

# True range (m) from true position
ranges_m = np.sqrt(
    df["true_pos_x"] ** 2 + df["true_pos_y"] ** 2 + df["true_pos_z"] ** 2
).values

# Residuals: estimated minus true (only use rows with valid out_*)
valid = (
    df["out_x_centroid"].notna()
    & df["out_y_centroid"].notna()
    & df["out_r_apparent"].notna()
    & df["true_x_centroid"].notna()
    & df["true_y_centroid"].notna()
    & df["true_r_apparent"].notna()
)

# Cutoff: keep only range <= 20e6 m
RANGE_CUTOFF_M = 20e6
valid = valid & (ranges_m <= RANGE_CUTOFF_M)

ranges_valid = ranges_m[valid]
centroid_x_residual_px = (
    df.loc[valid, "out_x_centroid"] - df.loc[valid, "true_x_centroid"]
).values
centroid_y_residual_px = (
    df.loc[valid, "out_y_centroid"] - df.loc[valid, "true_y_centroid"]
).values
radius_residual_px = (
    df.loc[valid, "out_r_apparent"] - df.loc[valid, "true_r_apparent"]
).values

# Cut out outliers: keep points within 3 IQR of median for each residual
def mask_outliers_iqr(x, k=1.5):
    q1, q3 = np.nanpercentile(x, [25, 75])
    iqr = q3 - q1
    if iqr <= 0:
        return np.ones_like(x, dtype=bool)
    return (x >= q1 - k * iqr) & (x <= q3 + k * iqr)

inlier_x = mask_outliers_iqr(centroid_x_residual_px)
inlier_y = mask_outliers_iqr(centroid_y_residual_px)
inlier_r = mask_outliers_iqr(radius_residual_px)
inlier = inlier_x & inlier_y & inlier_r
ranges_valid = ranges_valid[inlier]
# Series key: FOV (deg) only — FOV_deg ≈ 2 * arctan((res * pixel_pitch) / (2 * focal_length)) * 180/pi
_res = df.loc[valid, "cam_x_resolution"].values
_fl = df.loc[valid, "cam_focal_length"].values
_pp = df.loc[valid, "cam_x_pixel_pitch"].values
fov_deg = np.degrees(2 * np.arctan((_res * _pp) / (2 * _fl)))
fov_deg = np.round(fov_deg, 1)
_pass_ids_raw = np.asarray(fov_deg, dtype=str) + "deg"
pass_ids = _pass_ids_raw[inlier].tolist()

# Camera type = resolution (e.g. "512x512", "1024x1024")
cam_type_res = (
    df.loc[valid, "cam_x_resolution"].astype(int).astype(str).values
    + "x"
    + df.loc[valid, "cam_y_resolution"].astype(int).astype(str).values
)
cam_types = np.unique(cam_type_res[inlier])

if valid.sum() < 3:
    print("Need at least 3 rows with valid centroid/r to plot; skipping.")
else:
    plot_df_full = df.loc[valid].iloc[inlier].copy()
    plot_df_full["pass_id"] = pass_ids

    for cam_type in cam_types:
        mask_cam = (cam_type_res[inlier] == cam_type)
        if mask_cam.sum() < 3:
            continue
        plot_df = plot_df_full.iloc[mask_cam].copy()

        centroid_1sigma_px = float(
            np.nanstd(
                np.r_[
                    centroid_x_residual_px[inlier][mask_cam],
                    centroid_y_residual_px[inlier][mask_cam],
                ]
            )
            or 1.0
        )
        radius_1sigma_px = float(
            np.nanstd(radius_residual_px[inlier][mask_cam]) or 1.0
        )

        # Plot centroid residuals (X/Y) vs range — one figure per camera type
        plot_centroid_residuals_in_illumination_frame(
            plot_df,
            centroid_1sigma_px=centroid_1sigma_px,
            target_label="Earth",
            save_path=None,
        )

        # Plot radius residual vs range — one figure per camera type
        plot_radius_residuals_vs_range(
            plot_df,
            radius_1sigma_px=radius_1sigma_px,
            target_label="Earth",
            save_path=None,
        )

# %%
import numpy as np

# Norm of input (true) and output (estimated) positions per row
true_norm = np.sqrt(
    df["true_pos_x"] ** 2 + df["true_pos_y"] ** 2 + df["true_pos_z"] ** 2
).values
out_pos_valid = (
    df["out_pos_x"].notna() & df["out_pos_y"].notna() & df["out_pos_z"].notna()
)
out_norm = np.sqrt(
    df["out_pos_x"] ** 2 + df["out_pos_y"] ** 2 + df["out_pos_z"] ** 2
).values
out_norm = out_norm[out_pos_valid]

print("True position norm (m):")
print(f"  mean = {np.mean(true_norm):.2f}")
print(f"  std  = {np.std(true_norm):.2f}")
print("Output position norm (m), valid rows only:")
print(f"  mean = {np.mean(out_norm):.2f}")
print(f"  std  = {np.std(out_norm):.2f}")
# Out:
# True position norm (m):
#   mean = 14086666.67
#   std  = 8909984.41
# Output position norm (m), valid rows only:
#   mean = 14086678.08
#   std  = 8909945.61
